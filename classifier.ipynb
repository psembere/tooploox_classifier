# %%
from utils.data_loader import get_data_set, visualize

data_set = get_data_set()
X = data_set.data_batch[0]['data']
Y = [data_set.meta['label_names'][x] for x in data_set.data_batch[0]['labels']]
visualize(X, Y, (4, 12))
